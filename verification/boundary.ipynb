# %% [markdown]
# ### Import Lib

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.wkt import loads
import constant as c
from pyproj import CRS
import sys;sys.path.append('../')
from itertools import combinations
from sklearn.preprocessing import StandardScaler
import math
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import warnings; warnings.filterwarnings('ignore')

# %% [markdown]
# ### Acquire Data

# %%
# then read the data
df_2020 = pd.read_csv('../asset/preprocess/df_2020.csv', index_col=0)
df_2020['geometry_grids'] = df_2020['geometry_grids'].apply(lambda x: loads(x))
df_2021 = pd.read_csv('../asset/preprocess/df_2021.csv', index_col=0)
df_2021['geometry_grids'] = df_2021['geometry_grids'].apply(lambda x: loads(x))
df_2022 = pd.read_csv('../asset/preprocess/df_2022.csv', index_col=0)
df_2022['geometry_grids'] = df_2022['geometry_grids'].apply(lambda x: loads(x))

crs = 'EPSG:5179'  # Specify the coordinate reference system
gdf_2020 = gpd.GeoDataFrame(df_2020, geometry=df_2020['geometry_grids'], crs=crs)
gdf_2021 = gpd.GeoDataFrame(df_2021, geometry=df_2021['geometry_grids'], crs=crs)
gdf_2022 = gpd.GeoDataFrame(df_2022, geometry=df_2022['geometry_grids'], crs=crs)

gdf_2020_scbd = gdf_2020[gdf_2020['sigungunm'].isin(c.SCBD_NMS)]
gdf_2020_gbd = gdf_2020[gdf_2020['sigungunm'].isin(c.GBD_NMS)]
gdf_2020_ybd = gdf_2020[gdf_2020['sigungunm'].isin(c.YBD_NMS)]
gdf_2021_scbd = gdf_2021[gdf_2021['sigungunm'].isin(c.SCBD_NMS)]
gdf_2021_gbd = gdf_2021[gdf_2021['sigungunm'].isin(c.GBD_NMS)]
gdf_2021_ybd = gdf_2021[gdf_2021['sigungunm'].isin(c.YBD_NMS)]
gdf_2022_scbd = gdf_2022[gdf_2022['sigungunm'].isin(c.SCBD_NMS)]
gdf_2022_gbd = gdf_2022[gdf_2022['sigungunm'].isin(c.GBD_NMS)]
gdf_2022_ybd = gdf_2022[gdf_2022['sigungunm'].isin(c.YBD_NMS)]

# %%
# Setting COLS
SIM_CAL_COLS = c.SIM_CAL_COLS
STANDARDIZE_COLS = c.STANDARDIZE_COLS
PP_COLS = c.PP_COLS
BS_COLS = c.BS_COLS
BD_COLS = c.BD_COLS

# %% [markdown]
# ### Experiment Settings

# %%
# experiment settings
YEAR = 2020
CBD_NM = "scbd"

# %%
# Construct the DataFrame variable name
df_nm = f'gdf_{YEAR}_{CBD_NM}'
gdf = gpd.GeoDataFrame(locals()[df_nm], geometry='geometry_grids')
MAX_GRIDS_N = int(len(gdf) * 0.1)
print(f"Total Grids: {len(gdf)}\nNum Max grids: {MAX_GRIDS_N}")

# Set the CRS for the GeoDataFrame
crs = CRS.from_epsg(5179)
gdf = gdf.set_crs(crs)
gdf = gdf.dropna() # drop any data have null value

# and normailze
# Initialize the StandardScaler object
scaler = StandardScaler()
# Fit the scaler to the data
scaler.fit(gdf[STANDARDIZE_COLS])
# Transform the data using the scaler
normalized_data = scaler.transform(gdf[STANDARDIZE_COLS])
gdf_normalized = gdf.copy()
gdf_normalized[STANDARDIZE_COLS] = normalized_data
# Out:
# Total Grids: 1038
# Num Max grids: 103

# %% [markdown]
# #### OURS

# %%
# First, get the result data(phase_results)
result_fpath = f"../asset/experiment/cluster/{CBD_NM}_{YEAR}.csv"
phase_results = pd.read_csv(result_fpath)[['grid_idx', 'phase']]
phase_results['grid_idx'] = phase_results['grid_idx'].astype(int)
phase_results['phase'] = phase_results['phase'].astype(int)
cluster_idxs = list(phase_results.grid_idx)

gdf_ours = gdf_normalized.copy()
gdf_ours['cluster'] = np.where(gdf_ours['grid_idx'].isin(cluster_idxs), 1, 0)
num_grids = len(gdf_ours[gdf_ours['cluster'] == 1])
# gdf_ours.explore(column='cluster', cmap='Blues')

# %%
model_score = silhouette_score(gdf_ours[SIM_CAL_COLS], gdf_ours.cluster)
print("Score: ", model_score)
print("NUM GRIDS: ", num_grids)
gdf_ours.explore(column='cluster', cmap='Blues')
# Out:
# Score:  0.2421132877062531
# NUM GRIDS:  103
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33860b9cc3e3169fc89b6da6092ab1e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33860b9cc3e3169fc89b6da6092ab1e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33860b9cc3e3169fc89b6da6092ab1e9 = L.map(
#                 &quot;map_33860b9cc3e3169fc89b6da6092ab1e9&quot;,
#                 {
#                     center: [37.58353354982388, 126.98956000698061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_33860b9cc3e3169fc89b6da6092ab1e9);
#
#
#
#
#
#             var tile_layer_dbbe6855bda1d38c53caa8fa0fd8acc9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_33860b9cc3e3169fc89b6da6092ab1e9);
#
#
#             map_33860b9cc3e3169fc89b6da6092ab1e9.fitBounds(
#                 [[37.54889380981997, 126.95428278225035], [37.61817328982779, 127.02483723171089]],
#                 {}
#             );
#
#
#         function geo_json_da82082f3ac5dff5d3b7d550d07120be_styler(feature) {
#             switch(feature.id) {
#                 case &quot;770&quot;: case &quot;771&quot;: case &quot;783&quot;: case &quot;790&quot;: case &quot;797&quot;: case &quot;801&quot;: case &quot;802&quot;: case &quot;805&quot;: case &quot;810&quot;: case &quot;811&quot;: case &quot;812&quot;: case &quot;813&quot;: case &quot;824&quot;: case &quot;825&quot;: case &quot;826&quot;: case &quot;827&quot;: case &quot;839&quot;: case &quot;840&quot;: case &quot;850&quot;: case &quot;851&quot;: case &quot;859&quot;: case &quot;860&quot;: case &quot;861&quot;: case &quot;863&quot;: case &quot;864&quot;: case &quot;870&quot;: case &quot;871&quot;: case &quot;872&quot;: case &quot;874&quot;: case &quot;875&quot;: case &quot;876&quot;: case &quot;877&quot;: case &quot;878&quot;: case &quot;886&quot;: case &quot;887&quot;: case &quot;888&quot;: case &quot;889&quot;: case &quot;890&quot;: case &quot;896&quot;: case &quot;897&quot;: case &quot;898&quot;: case &quot;904&quot;: case &quot;905&quot;: case &quot;906&quot;: case &quot;908&quot;: case &quot;916&quot;: case &quot;917&quot;: case &quot;918&quot;: case &quot;919&quot;: case &quot;920&quot;: case &quot;928&quot;: case &quot;929&quot;: case &quot;935&quot;: case &quot;936&quot;: case &quot;941&quot;: case &quot;1198&quot;: case &quot;1208&quot;: case &quot;1230&quot;: case &quot;1231&quot;: case &quot;1241&quot;: case &quot;1242&quot;: case &quot;1243&quot;: case &quot;1254&quot;: case &quot;1255&quot;: case &quot;1256&quot;: case &quot;1265&quot;: case &quot;1266&quot;: case &quot;1276&quot;: case &quot;1277&quot;: case &quot;1278&quot;: case &quot;1279&quot;: case &quot;1280&quot;: case &quot;1289&quot;: case &quot;1299&quot;: case &quot;1300&quot;: case &quot;1302&quot;: case &quot;1308&quot;: case &quot;1309&quot;: case &quot;1313&quot;: case &quot;1315&quot;: case &quot;1317&quot;: case &quot;1322&quot;: case &quot;1323&quot;: case &quot;1324&quot;: case &quot;1325&quot;: case &quot;1326&quot;: case &quot;1330&quot;: case &quot;1331&quot;: case &quot;1333&quot;: case &quot;1334&quot;: case &quot;1335&quot;: case &quot;1340&quot;: case &quot;1341&quot;: case &quot;1343&quot;: case &quot;1344&quot;: case &quot;1350&quot;: case &quot;1352&quot;: case &quot;1353&quot;: case &quot;1354&quot;: case &quot;1361&quot;: case &quot;1362&quot;: case &quot;1363&quot;: case &quot;1364&quot;:
#                     return {&quot;color&quot;: &quot;#08306b&quot;, &quot;fillColor&quot;: &quot;#08306b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#f7fbff&quot;, &quot;fillColor&quot;: &quot;#f7fbff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_da82082f3ac5dff5d3b7d550d07120be_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_da82082f3ac5dff5d3b7d550d07120be_pointToLayer(feature, latlng)

# %% [markdown]
# #### Comparables(KNN)

# %%
# KNN with n_clusters = 10으로 지정
# 그 후 centroid cluster 대다수가 속한 cluster를 1, 아닌 클러스터를 0으로 지정

# %%
init_cluster_grid_idxs = phase_results[phase_results['phase'] == 0].grid_idx

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
gdf_knn = gdf_normalized.copy()
print(len(gdf_knn))
# Choose the number of clusters
n_clusters = 10 # for example

kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(gdf_knn[SIM_CAL_COLS])
gdf_knn['cluster'] = kmeans.labels_
# gdf_knn.explore(column='cluster', cmap='viridis') 
gdf_knn[gdf_knn['grid_idx'].isin(init_cluster_grid_idxs)].cluster


def get_cbd_label(init_cluster_grid_idxs, cluster_df):
    lst = cluster_df[cluster_df['grid_idx'].isin(init_cluster_grid_idxs)].cluster
    counts = {}
    for num in lst:
        counts[num] = counts.get(num, 0) + 1

    max_count = max(counts.values())
    most_common = [num for num, count in counts.items() if count == max_count]
    result = most_common[0]
    return result

cbd_label = get_cbd_label(init_cluster_grid_idxs, gdf_knn)
gdf_knn_ = gdf_knn.copy() # gdf_knn_ is for assigning new cluster(seperating cbd and non cbd)
gdf_knn_['cluster'] = gdf_knn_['cluster'].apply(lambda x: 1 if x == cbd_label else 0)
num_grids = len(gdf_knn_[gdf_knn_['cluster'] == 1])
# Out:
# 974

# %%
model_score = silhouette_score(gdf_knn_[SIM_CAL_COLS], gdf_knn_.cluster)
print("Score: ", model_score)
print("NUM GRIDS: ", num_grids)
gdf_knn_.explore(column='cluster', cmap='Blues')
# Out:
# Score:  0.15302894408327372
# NUM GRIDS:  99
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9ba7157f761b82fecf28451125686c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9ba7157f761b82fecf28451125686c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9ba7157f761b82fecf28451125686c9 = L.map(
#                 &quot;map_d9ba7157f761b82fecf28451125686c9&quot;,
#                 {
#                     center: [37.58353354982388, 126.98956000698061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d9ba7157f761b82fecf28451125686c9);
#
#
#
#
#
#             var tile_layer_94ec59cecbf421b1fc5a3c4641aa3514 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9ba7157f761b82fecf28451125686c9);
#
#
#             map_d9ba7157f761b82fecf28451125686c9.fitBounds(
#                 [[37.54889380981997, 126.95428278225035], [37.61817328982779, 127.02483723171089]],
#                 {}
#             );
#
#
#         function geo_json_41f45054435d34dc466712d6712acd60_styler(feature) {
#             switch(feature.id) {
#                 case &quot;710&quot;: case &quot;783&quot;: case &quot;784&quot;: case &quot;790&quot;: case &quot;803&quot;: case &quot;812&quot;: case &quot;813&quot;: case &quot;816&quot;: case &quot;826&quot;: case &quot;845&quot;: case &quot;859&quot;: case &quot;860&quot;: case &quot;861&quot;: case &quot;870&quot;: case &quot;871&quot;: case &quot;872&quot;: case &quot;877&quot;: case &quot;880&quot;: case &quot;886&quot;: case &quot;887&quot;: case &quot;896&quot;: case &quot;904&quot;: case &quot;905&quot;: case &quot;906&quot;: case &quot;935&quot;: case &quot;999&quot;: case &quot;1011&quot;: case &quot;1024&quot;: case &quot;1158&quot;: case &quot;1165&quot;: case &quot;1168&quot;: case &quot;1174&quot;: case &quot;1178&quot;: case &quot;1179&quot;: case &quot;1180&quot;: case &quot;1181&quot;: case &quot;1183&quot;: case &quot;1190&quot;: case &quot;1197&quot;: case &quot;1198&quot;: case &quot;1200&quot;: case &quot;1201&quot;: case &quot;1205&quot;: case &quot;1206&quot;: case &quot;1207&quot;: case &quot;1208&quot;: case &quot;1213&quot;: case &quot;1223&quot;: case &quot;1224&quot;: case &quot;1227&quot;: case &quot;1230&quot;: case &quot;1231&quot;: case &quot;1238&quot;: case &quot;1241&quot;: case &quot;1250&quot;: case &quot;1251&quot;: case &quot;1252&quot;: case &quot;1260&quot;: case &quot;1262&quot;: case &quot;1263&quot;: case &quot;1265&quot;: case &quot;1266&quot;: case &quot;1267&quot;: case &quot;1273&quot;: case &quot;1274&quot;: case &quot;1275&quot;: case &quot;1277&quot;: case &quot;1279&quot;: case &quot;1280&quot;: case &quot;1286&quot;: case &quot;1288&quot;: case &quot;1289&quot;: case &quot;1299&quot;: case &quot;1300&quot;: case &quot;1305&quot;: case &quot;1308&quot;: case &quot;1317&quot;: case &quot;1323&quot;: case &quot;1326&quot;: case &quot;1329&quot;: case &quot;1331&quot;: case &quot;1334&quot;: case &quot;1335&quot;: case &quot;1342&quot;: case &quot;1343&quot;: case &quot;1348&quot;: case &quot;1350&quot;: case &quot;1352&quot;: case &quot;1353&quot;: case &quot;1354&quot;: case &quot;1359&quot;: case &quot;1361&quot;: case &quot;1362&quot;: case &quot;1363&quot;: case &quot;1365&quot;: case &quot;1375&quot;: case &quot;1388&quot;: case &quot;1400&quot;: case &quot;1408&quot;:
#                     return {&quot;color&quot;: &quot;#08306b&quot;, &quot;fillColor&quot;: &quot;#08306b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#f7fbff&quot;, &quot;fillColor&quot;: &quot;#f7fbff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_41f45054435d34dc466712d6712acd60_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_41f45054435d34dc466712d6712acd60_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: tru

# %%
# gdf_knn_.explore(column='cluster', cmap='Blues')
