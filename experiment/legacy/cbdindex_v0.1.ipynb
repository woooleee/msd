# %%
# for each grids, calculate CBD Index. CBD Index represents two;
# 1. CBDness
# 2. How each grid is similar to other grids in CBD Boundary

# for example, suppose there is very high building with sufficient people, business factor((1)suffices), 
# but if that building is not similar to other buildings around((2)not suffices) CBD Index must show low
# (=like Lionel messi in the amateur league, not in Ligue 1 league)

# %% [markdown]
# #### Import Lib

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.wkt import loads
import constant as c
from pyproj import CRS
import sys;sys.path.append('../')
from itertools import combinations
from sklearn.preprocessing import StandardScaler
import math
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')
from scipy.stats import norm

# %%
# then read the data
df_2020 = pd.read_csv('../asset/preprocess/df_2020.csv', index_col=0)
df_2020['geometry_grids'] = df_2020['geometry_grids'].apply(lambda x: loads(x))
df_2021 = pd.read_csv('../asset/preprocess/df_2021.csv', index_col=0)
df_2021['geometry_grids'] = df_2021['geometry_grids'].apply(lambda x: loads(x))
df_2022 = pd.read_csv('../asset/preprocess/df_2022.csv', index_col=0)
df_2022['geometry_grids'] = df_2022['geometry_grids'].apply(lambda x: loads(x))

crs = 'EPSG:5179'  # Specify the coordinate reference system
gdf_2020 = gpd.GeoDataFrame(df_2020, geometry=df_2020['geometry_grids'], crs=crs)
gdf_2021 = gpd.GeoDataFrame(df_2021, geometry=df_2021['geometry_grids'], crs=crs)
gdf_2022 = gpd.GeoDataFrame(df_2022, geometry=df_2022['geometry_grids'], crs=crs)

gdf_2020_scbd = gdf_2020[gdf_2020['sigungunm'].isin(c.SCBD_NMS)]
gdf_2020_gbd = gdf_2020[gdf_2020['sigungunm'].isin(c.GBD_NMS)]
gdf_2020_ybd = gdf_2020[gdf_2020['sigungunm'].isin(c.YBD_NMS)]
gdf_2021_scbd = gdf_2021[gdf_2021['sigungunm'].isin(c.SCBD_NMS)]
gdf_2021_gbd = gdf_2021[gdf_2021['sigungunm'].isin(c.GBD_NMS)]
gdf_2021_ybd = gdf_2021[gdf_2021['sigungunm'].isin(c.YBD_NMS)]
gdf_2022_scbd = gdf_2022[gdf_2022['sigungunm'].isin(c.SCBD_NMS)]
gdf_2022_gbd = gdf_2022[gdf_2022['sigungunm'].isin(c.GBD_NMS)]
gdf_2022_ybd = gdf_2022[gdf_2022['sigungunm'].isin(c.YBD_NMS)]

# %%
# Setting COLS
SIM_CAL_COLS = c.SIM_CAL_COLS
STANDARDIZE_COLS = c.STANDARDIZE_COLS
PP_COLS = c.PP_COLS
BS_COLS = c.BS_COLS
BD_COLS = c.BD_COLS

# %% [markdown]
# #### Experiment Settings / Get Data

# %%
YEAR    = 2022
CBD_NM  = "gbd"

# %%
fname = f"{CBD_NM}_{YEAR}.csv"
clus  = pd.read_csv(f'../asset/experiment/cluster/{fname}') 
gwrw  = pd.read_csv(f'../asset/experiment/gwr/{fname}')
gwrw['geometry_grids'] = gwrw['geometry_grids'].apply(lambda x: loads(x))
gwrw = gpd.GeoDataFrame(gwrw, geometry='geometry_grids')
crs = CRS.from_epsg(5179)
gwrw = gwrw.set_crs(crs)
gdf_index = gwrw.copy()

# get init gwrw(For init grids)
init_grid_gdf = clus[clus['phase'] == 0]
init_grid_idxs = list(init_grid_gdf.grid_idx.values.astype(int))
init_gwrw = gwrw[gwrw['grid_idx'].isin(init_grid_idxs)]

# get cluster gwrw(For all grids in cluster)
grid_idxs = list(clus.grid_idx.values.astype(int))
gwrw = gwrw[gwrw['grid_idx'].isin(grid_idxs)]

# get init coefficient values
col_nms = list(init_gwrw.columns)
gwr_columns = [col for col in col_nms if col.startswith('gwr_')]
gwr_columns.remove('gwr_r2') # we get only coef names
coef = init_gwrw[gwr_columns].mean()
print(coef.gwr_const + coef.values[1:].mean())
coef.to_csv(f"../asset/experiment/cbdindex/coef_{CBD_NM}_{YEAR}.csv")
coef
# Out:
# -2.7202931918175306
# gwr_const        -3.107450
# gwr_bs_elct       0.030841
# gwr_bs_ebit      -1.150074
# gwr_bd_height     0.560496
# gwr_bd_vintage    0.618437
# gwr_pp_od         3.589284
# gwr_pp_pop       -1.326041
# dtype: float64

# %% [markdown]
# #### Calculate CBD Index

# %%
# 1) CBD Ness
cbdnesses = []
for i in range(len(gwrw)):   
    row_data = gwrw.iloc[i]
    cbdness = coef.gwr_const 
    for coef_col_nm in list(coef.index):
        if coef_col_nm == 'gwr_const': 
            pass 
        else:
            col_nm = coef_col_nm[4:]
            # cbdness += norm.cdf(row_data[col_nm]) * coef[coef_col_nm]
            cbdness += row_data[col_nm] * coef[coef_col_nm]
    # cbdness = max(cbdness, 0)
    cbdness = norm.cdf(cbdness)
    cbdnesses.append(cbdness)
gwrw['cbdness'] = cbdnesses

# 2) Similarity Index
mean_gwrw = gwrw[STANDARDIZE_COLS].mean()
abs_diffs = gwrw[STANDARDIZE_COLS].sub(mean_gwrw).abs()
row_diffs = list(abs_diffs.mean(axis=1))
row_sims = [math.exp(-diff/10) for diff in row_diffs]
row_sims = norm.cdf(row_sims)
gwrw['sim'] = row_sims

# 1) * 2) -> CBD Index 
gwrw['cbdi'] = gwrw['cbdness'] * gwrw['sim']
gwrw['cbdi'] = gwrw['cbdi'] / gwrw['cbdi'].max() # scale from 0 to 1

# %%
gwrw.explore(column = 'pp_od', cmap = 'coolwarm')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91a707d16916acae9e257b79abbc1161 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91a707d16916acae9e257b79abbc1161&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91a707d16916acae9e257b79abbc1161 = L.map(
#                 &quot;map_91a707d16916acae9e257b79abbc1161&quot;,
#                 {
#                     center: [37.500363138473546, 127.04104012810666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_91a707d16916acae9e257b79abbc1161);
#
#
#
#
#
#             var tile_layer_0b07155303f07db0278c91a8562c8915 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91a707d16916acae9e257b79abbc1161);
#
#
#             map_91a707d16916acae9e257b79abbc1161.fitBounds(
#                 [[37.488610588480775, 127.0195519453869], [37.51211568846632, 127.06252831082641]],
#                 {}
#             );
#
#
#         function geo_json_498575d737d34b2348ef1aacc7bece61_styler(feature) {
#             switch(feature.id) {
#                 case &quot;511&quot;:
#                     return {&quot;color&quot;: &quot;#f7af91&quot;, &quot;fillColor&quot;: &quot;#f7af91&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;531&quot;: case &quot;860&quot;:
#                     return {&quot;color&quot;: &quot;#f59f80&quot;, &quot;fillColor&quot;: &quot;#f59f80&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;550&quot;: case &quot;1079&quot;:
#                     return {&quot;color&quot;: &quot;#f59d7e&quot;, &quot;fillColor&quot;: &quot;#f59d7e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;561&quot;: case &quot;577&quot;: case &quot;1037&quot;: case &quot;1173&quot;: case &quot;1216&quot;:
#                     return {&quot;color&quot;: &quot;#e57058&quot;, &quot;fillColor&quot;: &quot;#e57058&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;562&quot;:
#                     return {&quot;color&quot;: &quot;#ec7f63&quot;, &quot;fillColor&quot;: &quot;#ec7f63&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;563&quot;: case &quot;1036&quot;: case &quot;1217&quot;:
#                     return {&quot;color&quot;: &quot;#ee8468&quot;, &quot;fillColor&quot;: &quot;#ee8468&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;564&quot;:
#                     return {&quot;color&quot;: &quot;#ef886b&quot;, &quot;fillColor&quot;: &quot;#ef886b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;:
#                     return {&quot;color&quot;: &quot;#f18d6f&quot;, &quot;fillColor&quot;: &quot;#f18d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;572&quot;:
#                     return {&quot;color&quot;: &quot;#e36c55&quot;, &quot;fillColor&quot;: &quot;#e36c55&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;573&quot;:
#                     return {&quot;color&quot;: &quot;#dc5d4a&quot;, &quot;fillColor&quot;: &quot;#dc5d4a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;574&quot;: case &quot;1001&quot;:
#                     return {&quot;color&quot;: &quot;#da5a49&quot;, &quot;fillColor&quot;: &quot;#da5a49&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;575&quot;: case &quot;904&quot;:
#                     return {&quot;color&quot;: &quot;#df634e&quot;, &quot;fillColor&quot;: &quot;#df634e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;576&quot;:
#                     return {&quot;color&quot;: &quot;#e26952&quot;, &quot;fillColor&quot;: &quot;#e26952&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;583&quot;:
#                     return {&quot;color&quot;: &quot;#e67259&quot;, &quot;fillColor&quot;: &

# %%
gwrw.explore(column = 'pp_pop', cmap = 'coolwarm')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_510997d14ff0cd99d3c4f9d1de8dc064 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_510997d14ff0cd99d3c4f9d1de8dc064&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_510997d14ff0cd99d3c4f9d1de8dc064 = L.map(
#                 &quot;map_510997d14ff0cd99d3c4f9d1de8dc064&quot;,
#                 {
#                     center: [37.500363138473546, 127.04104012810666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_510997d14ff0cd99d3c4f9d1de8dc064);
#
#
#
#
#
#             var tile_layer_0fb147d5bf8179747ad2a47026b2ba84 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_510997d14ff0cd99d3c4f9d1de8dc064);
#
#
#             map_510997d14ff0cd99d3c4f9d1de8dc064.fitBounds(
#                 [[37.488610588480775, 127.0195519453869], [37.51211568846632, 127.06252831082641]],
#                 {}
#             );
#
#
#         function geo_json_49f618fdf5fe8b34b7e2fe0f502e1f71_styler(feature) {
#             switch(feature.id) {
#                 case &quot;511&quot;:
#                     return {&quot;color&quot;: &quot;#f7a98b&quot;, &quot;fillColor&quot;: &quot;#f7a98b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;531&quot;:
#                     return {&quot;color&quot;: &quot;#f6a385&quot;, &quot;fillColor&quot;: &quot;#f6a385&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;532&quot;: case &quot;564&quot;:
#                     return {&quot;color&quot;: &quot;#f7b79b&quot;, &quot;fillColor&quot;: &quot;#f7b79b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;550&quot;: case &quot;880&quot;:
#                     return {&quot;color&quot;: &quot;#f3c8b2&quot;, &quot;fillColor&quot;: &quot;#f3c8b2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;561&quot;:
#                     return {&quot;color&quot;: &quot;#f7aa8c&quot;, &quot;fillColor&quot;: &quot;#f7aa8c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;562&quot;: case &quot;576&quot;:
#                     return {&quot;color&quot;: &quot;#f7b194&quot;, &quot;fillColor&quot;: &quot;#f7b194&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;563&quot;:
#                     return {&quot;color&quot;: &quot;#f7ad90&quot;, &quot;fillColor&quot;: &quot;#f7ad90&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;: case &quot;933&quot;:
#                     return {&quot;color&quot;: &quot;#f2c9b4&quot;, &quot;fillColor&quot;: &quot;#f2c9b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;572&quot;: case &quot;965&quot;: case &quot;1075&quot;:
#                     return {&quot;color&quot;: &quot;#f39475&quot;, &quot;fillColor&quot;: &quot;#f39475&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;573&quot;:
#                     return {&quot;color&quot;: &quot;#f59c7d&quot;, &quot;fillColor&quot;: &quot;#f59c7d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;574&quot;: case &quot;1074&quot;:
#                     return {&quot;color&quot;: &quot;#f7a889&quot;, &quot;fillColor&quot;: &quot;#f7a889&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;577&quot;:
#                     return {&quot;color&quot;: &quot;#f7af91&quot;, &quot;fillColor&quot;: &quot;#f7af91&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;583&quot;: case &quot;617&quot;:
#                     return {&quot;color&quot;: &quot;#ec7f63&quot;, &quot;fillColor&quot;: &quot;#ec7f63&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;584&quot;:
#                     return {&quot;color&quot;: &quot;#f39577&quot;, &quot;fillColor&quot;: &quot;#f39577&quot;, &quot;fillOpacity&quot;: 0.5,

# %%
gwrw[['grid_idx', 'geometry_grids', 'sim', 'cbdness', 'cbdi']].explore(column = 'cbdi', cmap = 'coolwarm')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8dedd63eb8938ff4ae760c1f12b5138d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8dedd63eb8938ff4ae760c1f12b5138d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8dedd63eb8938ff4ae760c1f12b5138d = L.map(
#                 &quot;map_8dedd63eb8938ff4ae760c1f12b5138d&quot;,
#                 {
#                     center: [37.500363138473546, 127.04104012810666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8dedd63eb8938ff4ae760c1f12b5138d);
#
#
#
#
#
#             var tile_layer_033bd3dd7941d0215b3b1340da64e493 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8dedd63eb8938ff4ae760c1f12b5138d);
#
#
#             map_8dedd63eb8938ff4ae760c1f12b5138d.fitBounds(
#                 [[37.488610588480775, 127.0195519453869], [37.51211568846632, 127.06252831082641]],
#                 {}
#             );
#
#
#         function geo_json_48c3d40e65a5bfd28fd0317b2492c4da_styler(feature) {
#             switch(feature.id) {
#                 case &quot;511&quot;: case &quot;933&quot;: case &quot;937&quot;:
#                     return {&quot;color&quot;: &quot;#c12b30&quot;, &quot;fillColor&quot;: &quot;#c12b30&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;531&quot;: case &quot;561&quot;: case &quot;880&quot;: case &quot;904&quot;: case &quot;1216&quot;:
#                     return {&quot;color&quot;: &quot;#bb1b2c&quot;, &quot;fillColor&quot;: &quot;#bb1b2c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;532&quot;: case &quot;575&quot;: case &quot;964&quot;:
#                     return {&quot;color&quot;: &quot;#b50927&quot;, &quot;fillColor&quot;: &quot;#b50927&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;550&quot;:
#                     return {&quot;color&quot;: &quot;#f7b396&quot;, &quot;fillColor&quot;: &quot;#f7b396&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;562&quot;: case &quot;572&quot;: case &quot;574&quot;: case &quot;931&quot;: case &quot;963&quot;: case &quot;999&quot;: case &quot;1047&quot;:
#                     return {&quot;color&quot;: &quot;#b8122a&quot;, &quot;fillColor&quot;: &quot;#b8122a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;563&quot;: case &quot;906&quot;: case &quot;908&quot;: case &quot;909&quot;:
#                     return {&quot;color&quot;: &quot;#e0654f&quot;, &quot;fillColor&quot;: &quot;#e0654f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;564&quot;:
#                     return {&quot;color&quot;: &quot;#ca3b37&quot;, &quot;fillColor&quot;: &quot;#ca3b37&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;: case &quot;583&quot;: case &quot;588&quot;: case &quot;598&quot;:
#                     return {&quot;color&quot;: &quot;#ba162b&quot;, &quot;fillColor&quot;: &quot;#ba162b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;573&quot;: case &quot;577&quot;: case &quot;881&quot;:
#                     return {&quot;color&quot;: &quot;#bd1f2d&quot;, &quot;fillColor&quot;: &quot;#bd1f2d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;576&quot;: case &quot;585&quot;: case &quot;905&quot;:
#                     return {&quot;color&quot;: &quot;#c73635&quot;, &quot;fillColor&quot;: &quot;#c73635&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;584&quot;: case &quot;998&quot;:
#                     return {&quot;color&quot;: &quot;#c32e31&quot;, &quot;fillColor&quot;: &quot;#c32e31&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;586&quot;: case &quot;596&quot;: case &quot;932&quot;: case &quot;965&quot;: case &quot;966&quot;: case &quot;996&quot;: case &quot;1000&quot;: case &quot;1039&quot;:
#                     r

# %%
gwrw_kepler = gwrw[['grid_idx', 'bdnm','pp_pop', 'pp_od', 'bs_ebit', 'bd_platarea',
       'bd_archarea', 'bd_totarea', 'bd_totflrcnt', 'bd_elvtent', 'bs_gas',
       'bs_elct', 'bd_height', 'bd_ilp', 'bd_vintage', 'cbdness', 'sim',
       'cbdi', 'geometry_grids']]

# %%
gwrw_kepler.crs = 'epsg:5179'
gwrw_kepler = gwrw_kepler.to_crs('epsg:4326')
gwrw_kepler = gwrw_kepler[[col for col in gwrw_kepler.columns if col != 'geometry_grids'] + ['geometry_grids']]

# %%
gwrw_kepler.to_csv(f"../kepler/cbdi_{CBD_NM}_{YEAR}.csv", index = False)
