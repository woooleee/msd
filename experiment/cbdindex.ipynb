# %%
# for each grids, calculate CBD Index. CBD Index represents two;
# 1. CBDness
# 2. How each grid is similar to other grids in CBD Boundary

# for example, suppose there is very high building with sufficient people, business factor((1)suffices), 
# but if that building is not similar to other buildings around((2)not suffices) CBD Index must show low
# (=like Lionel messi in the amateur league, not in Ligue 1 league)

# %% [markdown]
# #### Import Lib

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.wkt import loads
import constant as c
from pyproj import CRS
import sys;sys.path.append('../')
from itertools import combinations
from sklearn.preprocessing import StandardScaler
import math
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')
from scipy.stats import norm

# %%
# then read the data
df_2020 = pd.read_csv('../asset/preprocess/df_2020.csv', index_col=0)
df_2020['geometry_grids'] = df_2020['geometry_grids'].apply(lambda x: loads(x))
df_2021 = pd.read_csv('../asset/preprocess/df_2021.csv', index_col=0)
df_2021['geometry_grids'] = df_2021['geometry_grids'].apply(lambda x: loads(x))
df_2022 = pd.read_csv('../asset/preprocess/df_2022.csv', index_col=0)
df_2022['geometry_grids'] = df_2022['geometry_grids'].apply(lambda x: loads(x))

crs = 'EPSG:5179'  # Specify the coordinate reference system
gdf_2020 = gpd.GeoDataFrame(df_2020, geometry=df_2020['geometry_grids'], crs=crs)
gdf_2021 = gpd.GeoDataFrame(df_2021, geometry=df_2021['geometry_grids'], crs=crs)
gdf_2022 = gpd.GeoDataFrame(df_2022, geometry=df_2022['geometry_grids'], crs=crs)

gdf_2020_scbd = gdf_2020[gdf_2020['sigungunm'].isin(c.SCBD_NMS)]
gdf_2020_gbd = gdf_2020[gdf_2020['sigungunm'].isin(c.GBD_NMS)]
gdf_2020_ybd = gdf_2020[gdf_2020['sigungunm'].isin(c.YBD_NMS)]
gdf_2021_scbd = gdf_2021[gdf_2021['sigungunm'].isin(c.SCBD_NMS)]
gdf_2021_gbd = gdf_2021[gdf_2021['sigungunm'].isin(c.GBD_NMS)]
gdf_2021_ybd = gdf_2021[gdf_2021['sigungunm'].isin(c.YBD_NMS)]
gdf_2022_scbd = gdf_2022[gdf_2022['sigungunm'].isin(c.SCBD_NMS)]
gdf_2022_gbd = gdf_2022[gdf_2022['sigungunm'].isin(c.GBD_NMS)]
gdf_2022_ybd = gdf_2022[gdf_2022['sigungunm'].isin(c.YBD_NMS)]

# %%
# Setting COLS
SIM_CAL_COLS = c.SIM_CAL_COLS
STANDARDIZE_COLS = c.STANDARDIZE_COLS
PP_COLS = c.PP_COLS
BS_COLS = c.BS_COLS
BD_COLS = c.BD_COLS

# %% [markdown]
# #### Experiment Settings / Get Data

# %%
YEAR    = 2022
CBD_NM  = "gbd"

# %%
fname = f"{CBD_NM}_{YEAR}.csv"
clus  = pd.read_csv(f'../asset/experiment/cluster/{fname}') 
# clus  = pd.read_csv(f'../asset/experiment/cluster/{CBD_NM}_{YEAR}_tval.csv') 
gwrw  = pd.read_csv(f'../asset/experiment/gwr/{fname}')
gwrw['geometry_grids'] = gwrw['geometry_grids'].apply(lambda x: loads(x))
gwrw = gpd.GeoDataFrame(gwrw, geometry='geometry_grids')
crs = CRS.from_epsg(5179)
gwrw = gwrw.set_crs(crs)
gdf_index = gwrw.copy()

# get init gwrw(For init grids)
init_grid_gdf = clus[clus['phase'] == 0]
init_grid_idxs = list(init_grid_gdf.grid_idx.values.astype(int))
init_gwrw = gwrw[gwrw['grid_idx'].isin(init_grid_idxs)]

# get cluster gwrw(For all grids in cluster)
grid_idxs = list(clus.grid_idx.values.astype(int))
gwrw = gwrw[gwrw['grid_idx'].isin(grid_idxs)]

# get init coefficient values
col_nms = list(init_gwrw.columns)
gwr_columns = [col for col in col_nms if col.startswith('gwr_')]
gwr_columns.remove('gwr_r2') # we get only coef names
coef = init_gwrw[gwr_columns].mean()
print(coef.gwr_const + coef.values[1:].mean())
coef.to_csv(f"../asset/experiment/cbdindex/coef_{CBD_NM}_{YEAR}.csv")
coef
# Out:
# -1.2738933035359734
# gwr_const        -1.610942
# gwr_bs_elct      -0.069853
# gwr_bs_ebit      -0.654860
# gwr_bd_height     0.684008
# gwr_bd_vintage    0.637018
# gwr_pp_od         2.083209
# gwr_pp_pop       -0.657230
# dtype: float64

# %% [markdown]
# #### Calculate CBD Index

# %%
# 1) CBD Ness
cbdnesses = []
for i in range(len(gwrw)):   
    row_data = gwrw.iloc[i]
    cbdness = coef.gwr_const 
    for coef_col_nm in list(coef.index):
        if coef_col_nm == 'gwr_const': 
            pass 
        else:
            col_nm = coef_col_nm[4:]
            # cbdness += norm.cdf(row_data[col_nm]) * coef[coef_col_nm]
            cbdness += row_data[col_nm] * coef[coef_col_nm]
    cbdnesses.append(cbdness)

cbdnesses_mean = np.mean(cbdnesses)
cbdnesses_std = np.std(cbdnesses)
cbdnesses = [(x - cbdnesses_mean) / cbdnesses_std for x in cbdnesses]
cbdnesses = norm.cdf(cbdnesses)
gwrw['cbdness'] = cbdnesses

# 2) Similarity Index
mean_gwrw = gwrw[STANDARDIZE_COLS].mean()
abs_diffs = gwrw[STANDARDIZE_COLS].sub(mean_gwrw).abs()
row_diffs = list(abs_diffs.mean(axis=1))
row_sims_exp = [math.exp(-diff) for diff in row_diffs]
row_sims_mean = np.mean(row_sims_exp)
row_sims_std = np.std(row_sims_exp)
row_sims_standardized = [(x - row_sims_mean) / row_sims_std for x in row_sims_exp]
row_sims = norm.cdf(row_sims_standardized)

# %%
row_sims = norm.cdf(row_sims)
gwrw['sim'] = row_sims

# 1) * 2) -> CBD Index 
gwrw['cbdi'] = gwrw['cbdness'] * gwrw['sim']
# gwrw['cbdi'] = gwrw['cbdi'] / gwrw['cbdi'].max() # scale from 0 to 1

# %%
gwrw[['grid_idx', 'geometry_grids', 'sim', 'cbdness', 'cbdi']].explore(column = 'cbdi', cmap = 'coolwarm')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46ec00ecdefcd2c758097e350ef3fe71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46ec00ecdefcd2c758097e350ef3fe71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46ec00ecdefcd2c758097e350ef3fe71 = L.map(
#                 &quot;map_46ec00ecdefcd2c758097e350ef3fe71&quot;,
#                 {
#                     center: [37.50258795101538, 127.0336750493509],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_46ec00ecdefcd2c758097e350ef3fe71);
#
#
#
#
#
#             var tile_layer_b6300eebf88d69110b8f9beae7adf65e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46ec00ecdefcd2c758097e350ef3fe71);
#
#
#             map_46ec00ecdefcd2c758097e350ef3fe71.fitBounds(
#                 [[37.48860160699978, 127.0195519453869], [37.51657429503098, 127.04779815331493]],
#                 {}
#             );
#
#
#         function geo_json_a0d9bad78e1d4ba66eee70fac8e16222_styler(feature) {
#             switch(feature.id) {
#                 case &quot;511&quot;:
#                     return {&quot;color&quot;: &quot;#f18f71&quot;, &quot;fillColor&quot;: &quot;#f18f71&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;531&quot;: case &quot;904&quot;: case &quot;1000&quot;:
#                     return {&quot;color&quot;: &quot;#f7a98b&quot;, &quot;fillColor&quot;: &quot;#f7a98b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;532&quot;:
#                     return {&quot;color&quot;: &quot;#ec8165&quot;, &quot;fillColor&quot;: &quot;#ec8165&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;548&quot;: case &quot;861&quot;:
#                     return {&quot;color&quot;: &quot;#e6d7cf&quot;, &quot;fillColor&quot;: &quot;#e6d7cf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;563&quot;:
#                     return {&quot;color&quot;: &quot;#f4c6af&quot;, &quot;fillColor&quot;: &quot;#f4c6af&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;564&quot;: case &quot;829&quot;: case &quot;995&quot;: case &quot;1134&quot;:
#                     return {&quot;color&quot;: &quot;#eed0c0&quot;, &quot;fillColor&quot;: &quot;#eed0c0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;:
#                     return {&quot;color&quot;: &quot;#f39778&quot;, &quot;fillColor&quot;: &quot;#f39778&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;572&quot;:
#                     return {&quot;color&quot;: &quot;#f7b093&quot;, &quot;fillColor&quot;: &quot;#f7b093&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;574&quot;:
#                     return {&quot;color&quot;: &quot;#e97a5f&quot;, &quot;fillColor&quot;: &quot;#e97a5f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;575&quot;:
#                     return {&quot;color&quot;: &quot;#e36c55&quot;, &quot;fillColor&quot;: &quot;#e36c55&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;576&quot;:
#                     return {&quot;color&quot;: &quot;#f08a6c&quot;, &quot;fillColor&quot;: &quot;#f08a6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;577&quot;: case &quot;828&quot;: case &quot;845&quot;: case &quot;967&quot;:
#                     return {&quot;color&quot;: &quot;#f6bea4&quot;, &quot;fillColor&quot;: &quot;#f6bea4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;583&quot;: case &quot;588&quot;: case &quot;827&quot;: case &quot;1216&quot;:
#                     return {&quot;color&quot;: &quot;#f6bda2&quot;, &quot;fillColor&quot;: &quot;#f6bda2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;586&quot;: case &quot;598&quot;: case &quot;1039&quot;:

# %%
gwrw.explore(column = 'pp_od', cmap = 'coolwarm')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d511ccb905674d129ea92980093d304 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d511ccb905674d129ea92980093d304&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d511ccb905674d129ea92980093d304 = L.map(
#                 &quot;map_0d511ccb905674d129ea92980093d304&quot;,
#                 {
#                     center: [37.50127069316925, 127.04273431224516],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0d511ccb905674d129ea92980093d304);
#
#
#
#
#
#             var tile_layer_bd537a7c72e2b5bbc186b9b2a2c6cb99 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d511ccb905674d129ea92980093d304);
#
#
#             map_0d511ccb905674d129ea92980093d304.fitBounds(
#                 [[37.48860160699978, 127.02294031366392], [37.51393977933873, 127.06252831082641]],
#                 {}
#             );
#
#
#         function geo_json_b45b0656e208bd823ef280504ea074b3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;561&quot;: case &quot;967&quot;:
#                     return {&quot;color&quot;: &quot;#dc5d4a&quot;, &quot;fillColor&quot;: &quot;#dc5d4a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;562&quot;: case &quot;907&quot;: case &quot;1002&quot;:
#                     return {&quot;color&quot;: &quot;#e57058&quot;, &quot;fillColor&quot;: &quot;#e57058&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;563&quot;:
#                     return {&quot;color&quot;: &quot;#ee8468&quot;, &quot;fillColor&quot;: &quot;#ee8468&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;564&quot;: case &quot;1081&quot;:
#                     return {&quot;color&quot;: &quot;#ee8669&quot;, &quot;fillColor&quot;: &quot;#ee8669&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;:
#                     return {&quot;color&quot;: &quot;#f08b6e&quot;, &quot;fillColor&quot;: &quot;#f08b6e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;572&quot;: case &quot;577&quot;:
#                     return {&quot;color&quot;: &quot;#e16751&quot;, &quot;fillColor&quot;: &quot;#e16751&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;573&quot;:
#                     return {&quot;color&quot;: &quot;#d24b40&quot;, &quot;fillColor&quot;: &quot;#d24b40&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;574&quot;: case &quot;966&quot;:
#                     return {&quot;color&quot;: &quot;#d1493f&quot;, &quot;fillColor&quot;: &quot;#d1493f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;575&quot;:
#                     return {&quot;color&quot;: &quot;#c43032&quot;, &quot;fillColor&quot;: &quot;#c43032&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;576&quot;: case &quot;585&quot;: case &quot;997&quot;:
#                     return {&quot;color&quot;: &quot;#de614d&quot;, &quot;fillColor&quot;: &quot;#de614d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;583&quot;:
#                     return {&quot;color&quot;: &quot;#f29274&quot;, &quot;fillColor&quot;: &quot;#f29274&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;584&quot;:
#                     return {&quot;color&quot;: &quot;#eb7d62&quot;, &quot;fillColor&quot;: &quot;#eb7d62&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;586&quot;: case &quot;588&quot;:
#                     return {&quot;color&quot;: &quot;#c12b30&quot;, &quot;fillColor&quot;: &quot;#c12b30&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;587&quot;:
#                     return {&quot;color&quot;: &quot;#ba162b&quot;, &quot;fillColor&quot;: &quot;#ba162b&quot;, &quot;fi

# %%
gwrw.explore(column = 'pp_pop', cmap = 'coolwarm')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8637c479bbd8a0e8e7af21c9d2259df3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8637c479bbd8a0e8e7af21c9d2259df3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8637c479bbd8a0e8e7af21c9d2259df3 = L.map(
#                 &quot;map_8637c479bbd8a0e8e7af21c9d2259df3&quot;,
#                 {
#                     center: [37.50127069316925, 127.04273431224516],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8637c479bbd8a0e8e7af21c9d2259df3);
#
#
#
#
#
#             var tile_layer_449fc50e0c2e9eb1e51cdf37f4e2b46c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8637c479bbd8a0e8e7af21c9d2259df3);
#
#
#             map_8637c479bbd8a0e8e7af21c9d2259df3.fitBounds(
#                 [[37.48860160699978, 127.02294031366392], [37.51393977933873, 127.06252831082641]],
#                 {}
#             );
#
#
#         function geo_json_f296143579e3b6654b7b45fe6ccca648_styler(feature) {
#             switch(feature.id) {
#                 case &quot;562&quot;:
#                     return {&quot;color&quot;: &quot;#f29072&quot;, &quot;fillColor&quot;: &quot;#f29072&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;563&quot;:
#                     return {&quot;color&quot;: &quot;#f08a6c&quot;, &quot;fillColor&quot;: &quot;#f08a6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;564&quot;:
#                     return {&quot;color&quot;: &quot;#e8765c&quot;, &quot;fillColor&quot;: &quot;#e8765c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;: case &quot;588&quot;:
#                     return {&quot;color&quot;: &quot;#ef886b&quot;, &quot;fillColor&quot;: &quot;#ef886b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;572&quot;: case &quot;598&quot;:
#                     return {&quot;color&quot;: &quot;#e36b54&quot;, &quot;fillColor&quot;: &quot;#e36b54&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;573&quot;: case &quot;1081&quot;: case &quot;1214&quot;:
#                     return {&quot;color&quot;: &quot;#e67259&quot;, &quot;fillColor&quot;: &quot;#e67259&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;574&quot;:
#                     return {&quot;color&quot;: &quot;#e97a5f&quot;, &quot;fillColor&quot;: &quot;#e97a5f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;575&quot;:
#                     return {&quot;color&quot;: &quot;#f6a385&quot;, &quot;fillColor&quot;: &quot;#f6a385&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;576&quot;:
#                     return {&quot;color&quot;: &quot;#f7a889&quot;, &quot;fillColor&quot;: &quot;#f7a889&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;583&quot;: case &quot;904&quot;:
#                     return {&quot;color&quot;: &quot;#d95847&quot;, &quot;fillColor&quot;: &quot;#d95847&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;584&quot;: case &quot;1295&quot;:
#                     return {&quot;color&quot;: &quot;#e0654f&quot;, &quot;fillColor&quot;: &quot;#e0654f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;585&quot;:
#                     return {&quot;color&quot;: &quot;#e46e56&quot;, &quot;fillColor&quot;: &quot;#e46e56&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;586&quot;:
#                     return {&quot;color&quot;: &quot;#f59d7e&quot;, &quot;fillColor&quot;: &quot;#f59d7e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;587&quot;:
#                     return {&quot;color&quot;: &quot;#f6a283&quot;, &quot;fillColor&quot;: &quot;#f6a283&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 cas

# %%
# gwrw.to_csv(f"../asset/experiment/cbdindex/cbdi_{CBD_NM}_{YEAR}_tval.csv", index = False)

# %%
gwrw.to_csv(f"../asset/experiment/cbdindex/cbdi_{CBD_NM}_{YEAR}.csv", index = False)

# %%
gwrw_kepler = gwrw[['grid_idx', 'bdnm','pp_pop', 'pp_od', 'bs_ebit', 'bd_platarea',
       'bd_archarea', 'bd_totarea', 'bd_totflrcnt', 'bd_elvtent', 'bs_gas',
       'bs_elct', 'bd_height', 'bd_ilp', 'bd_vintage', 'cbdness', 'sim',
       'cbdi', 'geometry_grids']]

# %%
gwrw_kepler.crs = 'epsg:5179'
gwrw_kepler = gwrw_kepler.to_crs('epsg:4326')
gwrw_kepler = gwrw_kepler[[col for col in gwrw_kepler.columns if col != 'geometry_grids'] + ['geometry_grids']]

# %%
gwrw_kepler.to_csv(f"../kepler/cbdi_{CBD_NM}_{YEAR}.csv", index = False)
