# %% [markdown]
# ### Import Lib

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.wkt import loads
import constant as c
from pyproj import CRS
from sklearn.neighbors import NearestNeighbors
import sys;sys.path.append('../')
from util.distance import sphere_distance
from itertools import combinations
from sklearn.preprocessing import StandardScaler
from libpysal.weights import Queen
import math
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')

# %% [markdown]
# ### Acquire Data

# %%
# then read the data
df_2020 = pd.read_csv('../asset/preprocess/df_2020.csv', index_col=0)
df_2020['geometry_grids'] = df_2020['geometry_grids'].apply(lambda x: loads(x))
df_2021 = pd.read_csv('../asset/preprocess/df_2021.csv', index_col=0)
df_2021['geometry_grids'] = df_2021['geometry_grids'].apply(lambda x: loads(x))
df_2022 = pd.read_csv('../asset/preprocess/df_2022.csv', index_col=0)
df_2022['geometry_grids'] = df_2022['geometry_grids'].apply(lambda x: loads(x))

crs = 'EPSG:5179'  # Specify the coordinate reference system
gdf_2020 = gpd.GeoDataFrame(df_2020, geometry=df_2020['geometry_grids'], crs=crs)
gdf_2021 = gpd.GeoDataFrame(df_2021, geometry=df_2021['geometry_grids'], crs=crs)
gdf_2022 = gpd.GeoDataFrame(df_2022, geometry=df_2022['geometry_grids'], crs=crs)

gdf_2020_scbd = gdf_2020[gdf_2020['sigungunm'].isin(c.SCBD_NMS)]
gdf_2020_gbd = gdf_2020[gdf_2020['sigungunm'].isin(c.GBD_NMS)]
gdf_2020_ybd = gdf_2020[gdf_2020['sigungunm'].isin(c.YBD_NMS)]
gdf_2021_scbd = gdf_2021[gdf_2021['sigungunm'].isin(c.SCBD_NMS)]
gdf_2021_gbd = gdf_2021[gdf_2021['sigungunm'].isin(c.GBD_NMS)]
gdf_2021_ybd = gdf_2021[gdf_2021['sigungunm'].isin(c.YBD_NMS)]
gdf_2022_scbd = gdf_2022[gdf_2022['sigungunm'].isin(c.SCBD_NMS)]
gdf_2022_gbd = gdf_2022[gdf_2022['sigungunm'].isin(c.GBD_NMS)]
gdf_2022_ybd = gdf_2022[gdf_2022['sigungunm'].isin(c.YBD_NMS)]

# %%
# Setting COLS
SIM_CAL_COLS = c.SIM_CAL_COLS
STANDARDIZE_COLS = c.STANDARDIZE_COLS
PP_COLS = c.PP_COLS
BS_COLS = c.BS_COLS
BD_COLS = c.BD_COLS

# %% [markdown]
# #### 1. Get Boundary

# %% [markdown]
# - Data preparation(calculating nearest grid_idx, and apply Standard Scaler)

# %%
# Function to find grid indexes within a radius of 300 meters
def find_neighbors_within_radius(gdf, grid_idx):
    target_geometry = gdf.loc[gdf['grid_idx'] == grid_idx, 'geometry'].centroid.values[0]
    # Calculate the distances between the target geometry and all other geometries
    distances = gdf['geometry'].centroid.distance(target_geometry)
    # Filter the grid indexes based on the specified radius
    neighbors = gdf.loc[distances <= 400, 'grid_idx'].tolist()
    neighbors = [idx for idx in neighbors if idx != grid_idx]
    return neighbors

def find_queen_neighbors(gdf, grid_idx):
    target_geometry = gdf.loc[gdf['grid_idx'] == grid_idx, 'geometry'].centroid.values[0]
    # Calculate the distances between the target geometry and all other geometries
    distances = gdf['geometry'].centroid.distance(target_geometry)
    # Filter the grid indexes based on the specified radius
    neighbors = gdf.loc[distances < 100*math.sqrt(2)+1, 'grid_idx'].tolist()
    neighbors = [idx for idx in neighbors if idx != grid_idx]
    return neighbors

def compare_mean(row1, rows, sim_cal_cols):
    """
    square the difference and sum for all columns and divide by 13 and make that root. 
    input is one row data and multiple rows data and sim_cal_cols. 
    :params row1: one row
    :params rows: multiple rows
    """
    row1_mean = np.mean(row1[sim_cal_cols])
    rows_mean = np.mean(rows[sim_cal_cols], axis=0)
    diff_squared = np.sum((row1_mean - rows_mean)**2)
    mean_diff = np.sqrt(diff_squared / len(sim_cal_cols))
    return mean_diff


def within_boundary_distance(gdf, sim_cal_cols) -> float:
    pairwise_distances = []
    for row1, row2 in combinations(gdf.iterrows(), 2):
        distance = sum(abs(row1[1][col] - row2[1][col]) for col in SIM_CAL_COLS)
        pairwise_distances.append(distance)
    average_distance = sum(pairwise_distances) / len(pairwise_distances)
    # boundary_similarity = math.exp(-(average_distance/100))
    # penalty = math.sqrt(len(gdf))
    # penalty = 1 / math.sqrt(len(pairwise_distances))
    return average_distance 

def within_boundary_similarity(dist, n_cluster) -> float:
    return math.exp(-dist/100)

# %%
# calculate the extent to which grids in CBD boundary are similar to each other
gdf = gpd.GeoDataFrame(gdf_2022_scbd, geometry='geometry_grids')
# Set the CRS for the GeoDataFrame
crs = CRS.from_epsg(5179)
gdf = gdf.set_crs(crs)
gdf = gdf.dropna() # drop any data have null value

# and normailze
# Initialize the StandardScaler object
scaler = StandardScaler()
# Fit the scaler to the data
scaler.fit(gdf[STANDARDIZE_COLS])
# Transform the data using the scaler
normalized_data = scaler.transform(gdf[STANDARDIZE_COLS])
gdf_normalized = gdf.copy()
gdf_normalized[STANDARDIZE_COLS] = normalized_data

# %%
centroid_gdf_idx = gdf_normalized['bd_height'].idxmax()
print(f'Centroid Building is {gdf_normalized.loc[centroid_gdf_idx].bdnm}\ngrid_idx is {gdf_normalized.loc[centroid_gdf_idx].grid_idx}')
centroid_grid_idx = [gdf_normalized.loc[centroid_gdf_idx].grid_idx][0]
# declare init_cluster
init_cluster = [centroid_grid_idx] +\
                find_queen_neighbors(gdf_normalized, centroid_grid_idx) +\
                find_neighbors_within_radius(gdf_normalized, centroid_grid_idx)
init_cluster = list(set(init_cluster))
centroid_geom = gdf_normalized[gdf_normalized['grid_idx'] == centroid_grid_idx].centroid.values[0]
# init_cluster.append(36735)
# Out:
# Centroid Building is SK서린동빌딩
# grid_idx is 25116

# %%
# 0607 ver3
prev_pass_idxs = init_cluster
cluster = init_cluster
n_init_cluster = len(init_cluster)
mean_ilp_init_cluster = gdf_normalized[gdf_normalized['grid_idx'].isin(init_cluster)]['bd_ilp'].mean()
print(f'!! INIT CLUSTER: {init_cluster}\n!! INIT ILP: {mean_ilp_init_cluster}')
# data = {'grid_idx': init_cluster, 'mean_diffs': [0]*n_init_cluster, \
#         'final_diffs': [0]*n_init_cluster, 'phase': [0]*n_init_cluster}
# phase_results = pd.DataFrame(data)
init_zeros = [0] * n_init_cluster
data = {'grid_idx': init_cluster, 'bd_diff': init_zeros, \
        'bs_diff': init_zeros, 'pp_diff': init_zeros,\
        'sum_diff': init_zeros, 'phase': init_zeros,\
        'geom_dist': init_zeros, 'geom_feature_dist': init_zeros, 'pw_dist': init_zeros, \
            'final_cal': init_zeros}

phase_results = pd.DataFrame(data)

# experiment settings
TOPK = 3 # number of grids selected for each clustering phase
PHASE_N = 50

for phase in range(PHASE_N):
    # 1) GET TBA INDEXS IN THIS PHASE
    if phase > 0:
        this_tba_idxs = prev_fail_idxs # tba idx for this phase contained failed idx in the prev phase
    else:
        this_tba_idxs = [] # for the first phase, there is no prev fail idx so that we declare null list
    
    for prev_pass_idx in prev_pass_idxs:
        tba_idx = find_queen_neighbors(gdf_normalized, prev_pass_idx)
        this_tba_idxs = this_tba_idxs + tba_idx
    # print(this_tba_idxs)

    if not len(this_tba_idxs) > 0: break
    this_tba_idxs = list(set(this_tba_idxs)- set(cluster))
    
    # 2) CALCULATE FEATURE DISTANCE
    idxs = []
    bd_diffs = []
    pp_diffs = []
    bs_diffs = []
    sum_diffs = []
    geom_dists = []
    final_cals = []
    geom_feature_dists = []

    
    for tba_idx in this_tba_idxs:
        copied_cluster = cluster[:]
        cluster_gdf    = gdf_normalized[gdf_normalized['grid_idx'].isin(copied_cluster)]
        tba_gdf        = gdf_normalized[gdf_normalized['grid_idx'] == tba_idx]

        # mean_diff      = float(compare_mean(tba_gdf, cluster_gdf, SIM_CAL_COLS))
        bd_diff        = float(compare_mean(tba_gdf, cluster_gdf, BD_COLS))
        pp_diff        = float(compare_mean(tba_gdf, cluster_gdf, PP_COLS)) 
        bs_diff        = float(compare_mean(tba_gdf, cluster_gdf, BS_COLS))
        ilp_diff       = float(abs(tba_gdf.bd_ilp - mean_ilp_init_cluster))
        sum_diff       = bd_diff + pp_diff + bs_diff + ilp_diff

        geom_dist      = tba_gdf.centroid.distance(centroid_geom).values[0]/1000 # in kilometers
        # dist_penalty   = math.exp(-dist)
        dist_penalty   = 1/geom_dist
        geom_feature_dist  = sum_diff * geom_dist

        # print(dist)
        # print(mean_diff)
        idxs.append(tba_idx);
        bd_diffs.append(bd_diff)
        bs_diffs.append(bs_diff)
        pp_diffs.append(pp_diff)
        sum_diffs.append(sum_diff)
        geom_dists.append(geom_dist)
        geom_feature_dists.append(geom_feature_dist)

    # 3) GET 3 GRID_IDX which is near to CLUSTER
    # data = {'grid_idx': idxs, 'mean_diffs': mean_diffs, 'final_diffs': final_diffs}
    data = {'grid_idx': idxs, 'bd_diff': bd_diffs, \
            'bs_diff': bs_diffs, 'pp_diff': pp_diffs, \
            'sum_diff': sum_diffs, 'geom_dist': geom_dists,
            'geom_feature_dist': geom_feature_dists
    }
    
    result_df = pd.DataFrame(data)
    # print(final_diffs)
    selected_df = result_df.nsmallest(TOPK, 'sum_diff')
    selected_df['phase'] = [phase + 1] * len(selected_df)

    # 4) AND MAKE PHASE RESULTS AND NEW CLUSTER
    phase_results = pd.concat([phase_results, selected_df], axis = 0)
    this_pass_idxs =  list(selected_df['grid_idx'])
    this_fail_idxs = [x for x in this_tba_idxs if x not in this_pass_idxs]
    cluster = cluster + this_pass_idxs



    # 6) For given phase_result we calculate PAIRWISE SIMILARITY
    this_cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster)]
    pw_dist = within_boundary_distance(this_cluster_gdf, SIM_CAL_COLS) # pair wise distance

    phase_results.loc[phase_results['phase'] == phase+1, 'pw_dist'] = pw_dist
    mean_geom_feature_dist = \
        phase_results[phase_results['grid_idx'].isin(this_pass_idxs)].geom_feature_dist.mean()
    final_cal = \
        mean_geom_feature_dist * pw_dist
    phase_results.loc[phase_results['grid_idx'].isin(this_pass_idxs), 'final_cal'] = final_cal
    # 5) CHANGE VARIABLE NAME FOR NEXT PHASE
    prev_pass_idxs = this_pass_idxs
    prev_fail_idxs = this_fail_idxs

# phase_results
# Out:
# !! INIT CLUSTER: [26120, 26121, 25226, 25227, 26122, 26137, 26138, 25116, 25117, 25118, 25119, 24864, 24995, 24996, 26153, 26154, 26170, 25275, 25276, 25171, 25172, 25173, 25174, 26076, 25058, 24930, 24931, 25316, 26105]
# !! INIT ILP: 1.980689585790147

# %%
phase_results.plot(x='phase', y = 'final_cal')
# Out:
# <Axes: xlabel='phase'>

# %%
cluster_idxs = list(phase_results.grid_idx)
cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster_idxs)]
cluster_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59b9840c088371af6484a8d145cc1a89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59b9840c088371af6484a8d145cc1a89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59b9840c088371af6484a8d145cc1a89 = L.map(
#                 &quot;map_59b9840c088371af6484a8d145cc1a89&quot;,
#                 {
#                     center: [37.566360019454486, 126.98407612315526],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_59b9840c088371af6484a8d145cc1a89);
#
#
#
#
#
#             var tile_layer_9d140824680e445971892e23cf77f2d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_59b9840c088371af6484a8d145cc1a89);
#
#
#             map_59b9840c088371af6484a8d145cc1a89.fitBounds(
#                 [[37.55596742129975, 126.97161521875226], [37.57675261760922, 126.99653702755825]],
#                 {}
#             );
#
#
#         function geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0f0634f3d801fff9c7eb7e540c14ee5b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0f0634f3d801fff9c7eb7e540c14ee5b = L.geoJson(null, {
#                 onEachFeature: geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_onEachFeature,
#
#                 style: geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_styler,
#                 pointToLayer: geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_pointToLayer
#         });
#
#         function geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_add (data) {
#             geo_json_0f0634f3d801fff9c7eb7e540c14ee5b
#                 .addData(data)
#                 .addTo(map_59b9840c088371af6484a8d145cc1a89);
#         }
#             geo_json_0f0634f3d801fff9c7eb7e540c14ee5b_add({&quot;bbox&quot;: [126.97161521875226, 37.55596742129975, 126.99653702755825, 37.57675261760922], &quot;features&quot;: [{&quot;bbox&quot;: [126.972696647362, 37.569482153600156, 126.97383535260043, 37.570388523761736], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.97270300167082, 37.569482153600156], [126.972696647362, 37.57038347129912], [126.97382901193572, 37.570388523761736], [126.97383535260043, 37.569487205899335], [126.97270300167082, 37.569482153600156]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;784&quot;, &quot;properties&quot;: {&quot;bd_archarea&quot;: 0.29538423197265457, &quot;bd_elvten

# %%
cluster_gdf.to_csv('../kepler/scbd_clusters.csv', index = False)

# %%
phase_results.to_csv('foo.csv')

# %%
min_values = phase_results.groupby('phase')['final_cal'].min()
min_values.plot()
# Out:
# <Axes: xlabel='phase'>

# %%
gdf_normalized.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba9c4e315e09985c0c8eeaafd3894db2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba9c4e315e09985c0c8eeaafd3894db2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba9c4e315e09985c0c8eeaafd3894db2 = L.map(
#                 &quot;map_ba9c4e315e09985c0c8eeaafd3894db2&quot;,
#                 {
#                     center: [37.58353354982388, 126.98956000698061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ba9c4e315e09985c0c8eeaafd3894db2);
#
#
#
#
#
#             var tile_layer_2c9ca3cf4f068426b5f8cf984b4583d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba9c4e315e09985c0c8eeaafd3894db2);
#
#
#             map_ba9c4e315e09985c0c8eeaafd3894db2.fitBounds(
#                 [[37.54889380981997, 126.95428278225035], [37.61817328982779, 127.02483723171089]],
#                 {}
#             );
#
#
#         function geo_json_c4fb2455aba730d6ffd2de023651465e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c4fb2455aba730d6ffd2de023651465e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c4fb2455aba730d6ffd2de023651465e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_c4fb2455aba730d6ffd2de023651465e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c4fb2455aba730d6ffd2de023651465e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_c4fb2455aba730d6ffd2de023651465e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c4fb2455aba730d6ffd2de023651465e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c4fb2455aba730d6ffd2de023651465e = L.geoJson(null, {
#                 onEachFeature: geo_json_c4fb2455aba730d6ffd2de023651465e_onEachFeature,
#
#                 style: geo_json_c4fb2455aba730d6ffd2de023651465e_styler,
#                 pointToLayer: geo_json_c4fb2455aba730d6ffd2de023651465e_pointToLayer
#         });
#
#         function geo_json_c4fb2455aba730d6ffd2de023651465e_add (data) {
#             geo_json_c4fb2455aba730d6ffd2de023651465e
#                 .addData(data)
#                 .addTo(map_ba9c4e315e09985c0c8eeaafd3894db2);
#         }
#             geo_json_c4fb2455aba730d6ffd2de023651465e_add({&quot;bbox&quot;: [126.95428278225035, 37.54889380981997, 127.02483723171089, 37.61817328982779], &quot;features&quot;: [{&quot;bbox&quot;: [126.95428278225035, 37.60995887887419, 126.95542232895811, 37.6108654215022], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.95428936805341, 37.60995887887419], [126.95428278225035, 37.61086018765718], [126.9554157568263, 37.6108654215022], [126.95542232895811, 37.60996411254998], [126.95428936805341, 37.60995887887419]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;650&quot;, &quot;properties&quot;: {&quot;bd_archarea&quot;: -0.6900972653658178, &quot;bd_elvtent&quot

# %%
cluster_idxs = list(phase_results.grid_idx)
cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster_idxs)]
cluster_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65803bd45ba00dc9cb646f29f9504c9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65803bd45ba00dc9cb646f29f9504c9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65803bd45ba00dc9cb646f29f9504c9f = L.map(
#                 &quot;map_65803bd45ba00dc9cb646f29f9504c9f&quot;,
#                 {
#                     center: [37.56866271414363, 126.98912056841023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_65803bd45ba00dc9cb646f29f9504c9f);
#
#
#
#
#
#             var tile_layer_efcab065100ef504df2f92cb77c4e259 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_65803bd45ba00dc9cb646f29f9504c9f);
#
#
#             map_65803bd45ba00dc9cb646f29f9504c9f.fitBounds(
#                 [[37.5542586595478, 126.9670027118139], [37.583066768739464, 127.01123842500655]],
#                 {}
#             );
#
#
#         function geo_json_095a16f31f37803af3eaaf92e6e4245a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_095a16f31f37803af3eaaf92e6e4245a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_095a16f31f37803af3eaaf92e6e4245a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_095a16f31f37803af3eaaf92e6e4245a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_095a16f31f37803af3eaaf92e6e4245a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_095a16f31f37803af3eaaf92e6e4245a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_095a16f31f37803af3eaaf92e6e4245a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_095a16f31f37803af3eaaf92e6e4245a = L.geoJson(null, {
#                 onEachFeature: geo_json_095a16f31f37803af3eaaf92e6e4245a_onEachFeature,
#
#                 style: geo_json_095a16f31f37803af3eaaf92e6e4245a_styler,
#                 pointToLayer: geo_json_095a16f31f37803af3eaaf92e6e4245a_pointToLayer
#         });
#
#         function geo_json_095a16f31f37803af3eaaf92e6e4245a_add (data) {
#             geo_json_095a16f31f37803af3eaaf92e6e4245a
#                 .addData(data)
#                 .addTo(map_65803bd45ba00dc9cb646f29f9504c9f);
#         }
#             geo_json_095a16f31f37803af3eaaf92e6e4245a_add({&quot;bbox&quot;: [126.9670027118139, 37.5542586595478, 127.01123842500655, 37.583066768739464], &quot;features&quot;: [{&quot;bbox&quot;: [126.9670155594476, 37.57216067941125, 126.9681543732773, 37.57306710313302], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.96702198283518, 37.57216067941125], [126.9670155594476, 37.573061995871115], [126.96814796353554, 37.57306710313302], [126.9681543732773, 37.572165786507945], [126.96702198283518, 37.57216067941125]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;710&quot;, &quot;properties&quot;: {&quot;bd_archarea&quot;: -0.46467020524497316, &quot;bd_elvtent&quot

# %%
cluster_idxs = list(phase_results[phase_results['phase']<=72].grid_idx)
cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster_idxs)]
cluster_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d0099ae0843d1b9cddec3b384d6f885 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d0099ae0843d1b9cddec3b384d6f885&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d0099ae0843d1b9cddec3b384d6f885 = L.map(
#                 &quot;map_3d0099ae0843d1b9cddec3b384d6f885&quot;,
#                 {
#                     center: [37.50126231876857, 127.03934035183906],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3d0099ae0843d1b9cddec3b384d6f885);
#
#
#
#
#
#             var tile_layer_1177fcf4bc9ee30f9dab5d96e5f02e33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3d0099ae0843d1b9cddec3b384d6f885);
#
#
#             map_3d0099ae0843d1b9cddec3b384d6f885.fitBounds(
#                 [[37.49041326475851, 127.0195519453869], [37.51211137277862, 127.05912875829122]],
#                 {}
#             );
#
#
#         function geo_json_3a695ec563960864b0d9c7d418c26af0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3a695ec563960864b0d9c7d418c26af0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3a695ec563960864b0d9c7d418c26af0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3a695ec563960864b0d9c7d418c26af0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3a695ec563960864b0d9c7d418c26af0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_3a695ec563960864b0d9c7d418c26af0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3a695ec563960864b0d9c7d418c26af0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3a695ec563960864b0d9c7d418c26af0 = L.geoJson(null, {
#                 onEachFeature: geo_json_3a695ec563960864b0d9c7d418c26af0_onEachFeature,
#
#                 style: geo_json_3a695ec563960864b0d9c7d418c26af0_styler,
#                 pointToLayer: geo_json_3a695ec563960864b0d9c7d418c26af0_pointToLayer
#         });
#
#         function geo_json_3a695ec563960864b0d9c7d418c26af0_add (data) {
#             geo_json_3a695ec563960864b0d9c7d418c26af0
#                 .addData(data)
#                 .addTo(map_3d0099ae0843d1b9cddec3b384d6f885);
#         }
#             geo_json_3a695ec563960864b0d9c7d418c26af0_add({&quot;bbox&quot;: [127.0195519453869, 37.49041326475851, 127.05912875829122, 37.51211137277862], &quot;features&quot;: [{&quot;bbox&quot;: [127.0195519453869, 37.502982023121746, 127.02068907520031, 37.50388795364171], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0195577212058, 37.502982023121746], [127.0195519453869, 37.5038833574954], [127.02068331298115, 37.50388795364171], [127.02068907520031, 37.5029866191193], [127.0195577212058, 37.502982023121746]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2214&quot;, &quot;properties&quot;: {&quot;bd_archarea&quot;: -0.4529288715439579, &quot;bd_elvtent&quot;

# %%
cluster_gdf.to_csv('../kepler/scbd_clusters.csv', index = False)

# %%
cluster_gdf
# Out:
#       grid_idx    pp_pop     pp_od   bs_ebit  \
# 2214     31101  1.221243  1.628110  0.251356
# 2234     31161  1.255480  1.741217  0.334463
# 2235     31162  1.141415  1.693693  0.349022
# 2253     31220  1.012219  1.745371  0.415483
# 2264     31268  1.213744  2.001831  0.366112
# ...        ...       ...       ...       ...
# 3582     37527 -0.276546  0.041636  0.261043
# 3601     37588  0.061502  0.041571  0.227487
# 3603     37590 -0.164166  0.066655  0.276141
# 3604     37591 -0.285118 -0.102399  0.227281
# 3622     37651  0.190735 -0.012931  0.151518
#
#                                          geometry_grids sigungunm  \
# 2214  POLYGON ((957535.230 1944965.548, 957535.230 1...       서초구
# 2234  POLYGON ((957635.230 1944865.548, 957635.230 1...       서초구
# 2235  POLYGON ((957635.230 1944965.548, 957635.230 1...       서초구
# 2253  POLYGON ((957735.230 1945065.548, 957735.230 1...       서초구
# 2264  POLYGON ((957835.230 1944365.548, 957835.230 1...       서초구
# ...                                                 ...       ...
# 3582  POLYGON ((960835.230 1945565.548, 960835.230 1...       강남구
# 3601  POLYGON ((960935.230 1945265.548, 960935.230 1...       강남구
# 3603  POLYGON ((960935.230 1945465.548, 960935.230 1...       강남구
# 3604  POLYGON ((960935.230 1945565.548, 960935.230 1...       강남구
# 3622  POLYGON ((961035.230 1945265.548, 961035.230 1...       강남구
#
#                      platplc           x          y         x_5179  ...  \
# 2214   서울특별시 서초구 반포동 745-5번지  127.020404  37.503630  957610.363362  ...
# 2234  서울특별시 서초구 서초동 1302-2번지  127.021779  37.502677  957731.357450  ...
# 2235  서울특별시 서초구 서초동 1301-4번지  127.020802  37.502995  957645.240487  ...
# 2253  서울특별시 서초구 반포동 746-15번지  127.022465  37.504163  957792.817863  ...
# 2264  서울특별시 서초구 서초동 1316-3번지  127.024017  37.497903  957926.500839  ...
# ...                      ...         ...        ...            ...  ...
# 3582  서울특별시 강남구 삼성동 158-25번지  127.057792  37.508659  960917.619365  ...
# 3601  서울특별시 강남구 대치동 943-16번지  127.058947  37.506090  961018.351559  ...
# 3603  서울특별시 강남구 삼성동 158-23번지  127.058887  37.508003  961014.065786  ...
# 3604  서울특별시 강남구 삼성동 158-26번지  127.057998  37.508726  960935.845975  ...
# 3622  서울특별시 강남구 대치동 956-21번지  127.060177  37.505880  961126.925709  ...
#
#       bd_totarea bd_totflrcnt  bd_elvtent    bs_gas   bs_elct  bd_height  \
# 2214   -0.023057    -0.625577    0.404120  0.272817 -0.433748   2.234826
# 2234   -0.291207    -0.994438    0.404120 -0.252731 -0.200122   0.019847
# 2235    0.930635    -0.625577    1.611537  0.706286  0.478362   1.999663
# 2253   -0.112962     0.212744    0.068726 -0.203204 -0.157038  -0.214892
# 2264   -0.465111    -0.927372   -0.199589 -0.303968 -0.383682  -0.517214
# ...          ...          ...         ...       ...       ...        ...
# 3582    1.649712     3.364831    0.001647  1.002127  0.794677   0.197759
# 3601    1.137307     4.102554   -0.122190 -0.196273  0.898929   0.554952
# 3603    2.402554     1.721722    0.202884  1.181708  1.703223   1.349364
# 3604    0.687552     0.145679    0.404120  0.623319  0.285307   0.723217
# 3622    0.575402     3.063036   -0.257085  0.153754  0.349474   0.020165
#
#         bd_ilp  bd_vintage  count  \
# 2214  0.553670   -0.307986     11
# 2234  0.374451    1.818227      4
# 2235  0.596682    0.817656      4
# 2253  0.070675   -1.183486     14
# 2264  1.680508    0.817656     17
# ...        ...         ...    ...
# 3582  1.251727    0.057607      1
# 3601  1.326861   -0.625475      2
# 3603  3.471351    0.129763      3
# 3604  2.589595   -0.016153      3
# 3622  0.669714    0.362039      3
#
#                                                geometry
# 2214  POLYGON ((957535.230 1944965.548, 957535.230 1...
# 2234  POLYGON ((957635.230 1944865.548, 957635.230 1...
# 2235  POLYGON ((957635.230 1944965.548, 957635.230 1...
# 2253  POLYGON ((957735.230 1945065.548, 957735.230 1...
# 2264  POLYGON ((957835.230 1944365.548, 957835.230 1...
# ...                                                 ...
# 3582  POLYGON ((960835.230 1945565.548, 960835.230 1...
# 3601  POLYGON ((960935.230 1945265.548, 960935.230 1...
# 3603  POLYGON ((960935.230 1945465.548, 960935.230 1...
# 3604  POLYGON ((960935.230 1945565.548, 960935.230 1...
# 3622  POLYGON ((961035.230 1945265.548, 961035.230 1...
#
# [207 rows x 24 columns]

# %%
cluster_gdf.to_csv('cbd_clusters.csv', index = False)

# %%
cluster_gdf.crs
# Out:
# <Projected CRS: EPSG:5179>
# Name: Korea 2000 / Unified CS
# Axis Info [cartesian]:
# - X[north]: Northing (metre)
# - Y[east]: Easting (metre)
# Area of Use:
# - name: Republic of Korea (South Korea) - onshore and offshore.
# - bounds: (122.71, 28.6, 134.28, 40.27)
# Coordinate Operation:
# - name: Korea Unified Belt
# - method: Transverse Mercator
# Datum: Geocentric datum of Korea
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
import geopandas as gpd
from shapely.geometry import Polygon

# Assuming 'gdf' is your GeoDataFrame containing the grid polygons
# Create a new GeoDataFrame to store the periphery polygons
periphery_gdf = gpd.GeoDataFrame(columns=['periphery'], geometry='periphery')

# Iterate over each grid polygon
for _, row in cluster_gdf.iterrows():
    grid_polygon = row['geometry']
    outer_boundary = grid_polygon.exterior
    inner_holes = grid_polygon.interiors

    # Create a new polygon feature with the outer boundary and inner holes
    periphery_polygon = gpd.GeoSeries([Polygon(outer_boundary, inner_holes)])
    
    # Append the periphery polygon to the periphery GeoDataFrame
    periphery_gdf = periphery_gdf.append({'periphery': periphery_polygon}, ignore_index=True)

# Display the periphery polygons
print(periphery_gdf)
# Out:
#                                              periphery
# 0    0    POLYGON ((957535.230 1944965.548, 957535....
# 1    0    POLYGON ((957635.230 1944865.548, 957635....
# 2    0    POLYGON ((957635.230 1944965.548, 957635....
# 3    0    POLYGON ((957735.230 1944865.548, 957735....
# 4    0    POLYGON ((957735.230 1944965.548, 957735....
# ..                                                 ...
# 112  0    POLYGON ((959135.230 1944265.548, 959135....
# 113  0    POLYGON ((959135.230 1944365.548, 959135....
# 114  0    POLYGON ((959135.230 1945565.548, 959135....
# 115  0    POLYGON ((959235.230 1944065.548, 959235....
# 116  0    POLYGON ((959235.230 1944265.548, 959235....
#
# [117 rows x 1 columns]

# %%
periphery_gdf = gpd.GeoDataFrame(periphery_gdf, geometry='periphery')  # Convert DataFrame to GeoDataFrame
crs = CRS.from_epsg(5179)
periphery_gdf = periphery_gdf.set_crs(crs)
periphery_gdf.explore()
# Out:
# ---------------------------------------------------------------------------
# GeometryTypeError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 periphery_gdf = gpd.GeoDataFrame(periphery_gdf, geometry='periphery')  # Convert DataFrame to GeoDataFrame
#       2 crs = CRS.from_epsg(5179)
#       3 periphery_gdf = periphery_gdf.set_crs(crs)
#
# File ~/anaconda3/envs/msd2/lib/python3.9/site-packages/geopandas/geodataframe.py:191, in GeoDataFrame.__init__(self, data, geometry, crs, *args, **kwargs)
#     183     if (
#     184         hasattr(geometry, "crs")
#     185         and geometry.crs
#     186         and crs
#     187         and not geometry.crs == crs
#     188     ):
#     189         raise ValueError(crs_mismatch_error)
# --> 191     self.set_geometry(geometry, inplace=True, crs=crs)
#     193 if geometry is None and crs:
#     194     raise ValueError(
#     195         "Assigning CRS to a GeoDataFrame without a geometry column is not "
#     196         "supported. Supply geometry using the 'geometry=' keyword argument, "
#     197         "or by providing a DataFrame with column name 'geometry'",
#     198     )
#
# File ~/anaconda3/envs/msd2/lib/python3.9/site-packages/geopandas/geodataframe.py:348, in GeoDataFrame.set_geometry(self, col, drop, inplace, crs)
#     345     level.crs = crs
#     347 # Check that we are using a listlike of geometries
# --> 348 level = _ensure_geometry(level, crs=crs)
#     349 # update _geometry_column_name prior to assignment
#     350 # to avoid default is None warning
#     351 frame._geometry_column_name = geo_column_name
#
# File ~/anaconda3/envs/msd2/lib/python3.9/site-packages/geopandas/geodataframe.py:56, in _ensure_geometry(data, crs)
#      54 else:
#      55     if isinstance(data, Series):
# ---> 56         out = from_shapely(np.asarray(data), crs=crs)
#      57         return GeoSeries(out, index=data.index, name=data.name)
#      58     else:
#
# File ~/anaconda3/envs/msd2/lib/python3.9/site-packages/geopandas/array.py:158, in from_shapely(data, crs)
#     142 def from_shapely(data, crs=None):
#     143     """
#     144     Convert a list or array of shapely objects to a GeometryArray.
#     145
#    (...)
#     156
#     157     """
# --> 158     return GeometryArray(vectorized.from_shapely(data), crs=crs)
#
# File ~/anaconda3/envs/msd2/lib/python3.9/site-packages/geopandas/_vectorized.py:140, in from_shapely(data)
#     138         out.append(geom)
#     139 elif hasattr(geom, "__geo_interface__"):
# --> 140     geom = shapely.geometry.shape(geom)
#     141     if compat.USE_PYGEOS:
#     142         out.append(_shapely_to_pygeos(geom))
#
# File ~/anaconda3/envs/msd2/lib/python3.9/site-packages/shapely/geometry/geo.py:113, in shape(context)
#     111     return GeometryCollection(geoms)
#     112 else:
# --> 113     raise GeometryTypeError(f"Unknown geometry type: {geom_type!r}")
#
# GeometryTypeError: Unknown geometry type: 'featurecollection'

# %%
# # 0606 ver2
# prev_pass_idxs = init_cluster
# cluster = init_cluster

# print(f'!! INIT CLUSTER: {init_cluster}')
# n_init_cluster = len(init_cluster)
# data = {'grid_idx': init_cluster, 'diffs': [0]*n_init_cluster, 'phase': [0]*n_init_cluster}
# phase_results = pd.DataFrame(data)

# # experiment settings
# TOPK = 3 # number of grids selected for each clustering phase
# PHASE_N = 50

# for phase in range(PHASE_N):
#     # 1) GET TBA INDEXS IN THIS PHASE
#     if phase > 0:
#         this_tba_idxs = prev_fail_idxs # tba idx for this phase contained failed idx in the prev phase
#     else:
#         this_tba_idxs = [] # for the first phase, there is no prev fail idx so that we declare null list
    
#     for prev_pass_idx in prev_pass_idxs:
#         tba_idx = find_queen_neighbors(gdf_normalized, prev_pass_idx)
#         this_tba_idxs = this_tba_idxs + tba_idx
#     # print(this_tba_idxs)

#     if not len(this_tba_idxs) > 0: break
#     this_tba_idxs = list(set(this_tba_idxs)- set(cluster))
#     # print(f'!! {len(this_tba_idxs)} TBA indexs in\n{phase+1}th Phase')
#     # print(f'!! {cluster} were in cluster in prev phase')
    
#     # 2) CALCULATE FEATURE DISTANCE
#     idxs = []
#     diffs = []
    
#     for tba_idx in this_tba_idxs:
#         copied_cluster = cluster[:]
#         cluster_gdf    = gdf_normalized[gdf_normalized['grid_idx'].isin(copied_cluster)]
#         tba_gdf        = gdf_normalized[gdf_normalized['grid_idx'] == tba_idx]
#         mean_diff      = compare_mean(tba_gdf, cluster_gdf, SIM_CAL_COLS)
#         idxs.append(tba_idx); diffs.append(mean_diff)

#     # 3) GET 3 GRID_IDX which is near to CLUSTER
#     data = {'grid_idx': idxs, 'diffs': diffs}
#     result_df = pd.DataFrame(data)
#     selected_df = result_df.nsmallest(TOPK, 'diffs')
#     selected_df['phase'] = [phase + 1] * len(selected_df)

#     # 4) AND MAKE PHASE RESULTS AND NEW CLUSTER
#     phase_results = pd.concat([phase_results, selected_df], axis = 0)
#     this_pass_idxs =  list(selected_df['grid_idx'])
#     this_fail_idxs = [x for x in this_tba_idxs if x not in this_pass_idxs]
#     cluster = cluster + this_pass_idxs

#     # 5) CHANGE VARIABLE NAME FOR NEXT PHASE
#     prev_pass_idxs = this_pass_idxs
#     prev_fail_idxs = this_fail_idxs
# # phase_results
# Out:
# !! INIT CLUSTER: [26120, 26121, 25226, 25227, 26122, 26137, 26138, 25116, 25117, 25118, 25119, 24864, 24995, 24996, 26153, 26154, 26170, 25275, 25276, 25171, 25172, 25173, 25174, 26076, 25058, 24930, 25316, 26105]

# %%
def within_boundary_distance(gdf, sim_cal_cols) -> float:
    pairwise_distances = []
    for row1, row2 in combinations(gdf.iterrows(), 2):
        distance = sum(abs(row1[1][col] - row2[1][col]) for col in SIM_CAL_COLS)
        pairwise_distances.append(distance)
    # average_distance = sum(pairwise_distances) / len(pairwise_distances)
    average_distance = sum(pairwise_distances) / len(pairwise_distances)
    # boundary_similarity = math.exp(-(average_distance/100))
    penalty = math.sqrt(len(gdf))
    # penalty = 1 / math.sqrt(len(pairwise_distances))
    return average_distance * penalty

def within_boundary_similarity(dist, n_cluster) -> float:
    return math.exp(-dist/100)

# %%
phase_results.groupby('phase').mean('diffs')['diffs'].plot()
# Out:
# <Axes: xlabel='phase'>

# %%
phase_results[:50]
# Out:
#     grid_idx     diffs  phase
# 0      26120  0.000000      0
# 1      26121  0.000000      0
# 2      25226  0.000000      0
# 3      25227  0.000000      0
# 4      26122  0.000000      0
# 5      26137  0.000000      0
# 6      26138  0.000000      0
# 7      25116  0.000000      0
# 8      25117  0.000000      0
# 9      25118  0.000000      0
# 10     25119  0.000000      0
# 11     24864  0.000000      0
# 12     24995  0.000000      0
# 13     24996  0.000000      0
# 14     26153  0.000000      0
# 15     26154  0.000000      0
# 16     26170  0.000000      0
# 17     25275  0.000000      0
# 18     25276  0.000000      0
# 19     25171  0.000000      0
# 20     25172  0.000000      0
# 21     25173  0.000000      0
# 22     25174  0.000000      0
# 23     26076  0.000000      0
# 24     25058  0.000000      0
# 25     24930  0.000000      0
# 26     24931  0.000000      0
# 27     25316  0.000000      0
# 28     26105  0.000000      0
# 15     25318  0.621584      1
# 3      26136  0.626370      1
# 6      26168  0.635577      1
# 22     26104  0.737025      2
# 21     26103  0.791048      2
# 8      26167  0.804319      2
# 23     26087  0.791846      3
# 25     26102  0.837122      3
# 5      25360  0.885484      3
# 0      26117  0.548288      4
# 11     25393  0.768871      4
# 12     25394  0.829471      4
# 28     26086  0.831102      5
# 15     25277  0.886074      5
# 7      26133  0.912413      5
# 16     26182  0.899243      6
# 25     26072  0.911025      6
# 1      25356  0.918834      6
# 22     26057  0.772385      7
# 13     25391  0.896510      7
# 17     25278  0.911834      7

# %%
# Calculate SIMILARITY for each phase
dists = []
sims = []
for phase in range(50):
    cluster_idxs = list(phase_results[phase_results['phase']<= phase].grid_idx)
    cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster_idxs)]
    dist = within_boundary_distance(cluster_gdf, SIM_CAL_COLS)
    sim = within_boundary_similarity(dist, len(cluster_gdf))
    std_err = np.std(cluster_gdf['bd_ilp']/1000000)
    mean_var = cluster_gdf[SIM_CAL_COLS].var().mean()
    dists.append(dist)
    sims.append(sim)

# %%
plt.plot(sims)

# %%
plt.plot(dists)

# %%
cluster_idxs = list(phase_results.grid_idx)
cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster_idxs)]
cluster_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfbc1e1b4df7870407848a23076f19af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfbc1e1b4df7870407848a23076f19af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfbc1e1b4df7870407848a23076f19af = L.map(
#                 &quot;map_bfbc1e1b4df7870407848a23076f19af&quot;,
#                 {
#                     center: [37.50213287088166, 127.03312126699308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bfbc1e1b4df7870407848a23076f19af);
#
#
#
#
#
#             var tile_layer_096b6ebd09f315116f560fddbcd9b090 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bfbc1e1b4df7870407848a23076f19af);
#
#
#             map_bfbc1e1b4df7870407848a23076f19af.fitBounds(
#                 [[37.488610588480775, 127.02061991162765], [37.515655153282545, 127.0456226223585]],
#                 {}
#             );
#
#
#         function geo_json_aa26b1fd6fd356ed6e41912c0386d890_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_aa26b1fd6fd356ed6e41912c0386d890_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_aa26b1fd6fd356ed6e41912c0386d890_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_aa26b1fd6fd356ed6e41912c0386d890_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_aa26b1fd6fd356ed6e41912c0386d890_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_aa26b1fd6fd356ed6e41912c0386d890.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_aa26b1fd6fd356ed6e41912c0386d890_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_aa26b1fd6fd356ed6e41912c0386d890 = L.geoJson(null, {
#                 onEachFeature: geo_json_aa26b1fd6fd356ed6e41912c0386d890_onEachFeature,
#
#                 style: geo_json_aa26b1fd6fd356ed6e41912c0386d890_styler,
#                 pointToLayer: geo_json_aa26b1fd6fd356ed6e41912c0386d890_pointToLayer
#         });
#
#         function geo_json_aa26b1fd6fd356ed6e41912c0386d890_add (data) {
#             geo_json_aa26b1fd6fd356ed6e41912c0386d890
#                 .addData(data)
#                 .addTo(map_bfbc1e1b4df7870407848a23076f19af);
#         }
#             geo_json_aa26b1fd6fd356ed6e41912c0386d890_add({&quot;bbox&quot;: [127.02061991162765, 37.488610588480775, 127.0456226223585, 37.515655153282545], &quot;features&quot;: [{&quot;bbox&quot;: [127.02298045522568, 37.49758776678568, 127.02411746188967, 37.498493665191006], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.02298618871288, 37.49758776678568], [127.02298045522568, 37.498489102436295], [127.02411174199861, 37.498493665191006], [127.02411746188967, 37.497592329392695], [127.02298618871288, 37.49758776678568]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2232&quot;, &quot;properties&quot;: {&quot;bd_archarea&quot;: -0.3354058334360807, &quot;bd_el

# %%
data = sims
# Calculate the first differences
first_diff = [data[i + 1] - data[i] for i in range(len(data) - 1)]

# Calculate the second differences
second_diff = [first_diff[i + 1] - first_diff[i] for i in range(len(first_diff) - 1)]

# Find the index of the smallest second difference
min_index = second_diff.index(min(second_diff))

# %%
cluster_idxs = list(phase_results[phase_results['phase']<= min_index].grid_idx)
cluster_gdf = gdf_normalized[gdf_normalized['grid_idx'].isin(cluster_idxs)]
cluster_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bb712cbc04ada20c8791c84d50ac308 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bb712cbc04ada20c8791c84d50ac308&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bb712cbc04ada20c8791c84d50ac308 = L.map(
#                 &quot;map_6bb712cbc04ada20c8791c84d50ac308&quot;,
#                 {
#                     center: [37.527351807110485, 126.92659107169129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6bb712cbc04ada20c8791c84d50ac308);
#
#
#
#
#
#             var tile_layer_708bba6aaa1a14b1cbcddfc08f0e4c78 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6bb712cbc04ada20c8791c84d50ac308);
#
#
#             map_6bb712cbc04ada20c8791c84d50ac308.fitBounds(
#                 [[37.52419444704424, 126.92431728529574], [37.53050916717673, 126.92886485808684]],
#                 {}
#             );
#
#
#         function geo_json_b2d9cb477d755df1dad0a0049c08a072_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b2d9cb477d755df1dad0a0049c08a072_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b2d9cb477d755df1dad0a0049c08a072_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b2d9cb477d755df1dad0a0049c08a072_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b2d9cb477d755df1dad0a0049c08a072_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b2d9cb477d755df1dad0a0049c08a072.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b2d9cb477d755df1dad0a0049c08a072_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b2d9cb477d755df1dad0a0049c08a072 = L.geoJson(null, {
#                 onEachFeature: geo_json_b2d9cb477d755df1dad0a0049c08a072_onEachFeature,
#
#                 style: geo_json_b2d9cb477d755df1dad0a0049c08a072_styler,
#                 pointToLayer: geo_json_b2d9cb477d755df1dad0a0049c08a072_pointToLayer
#         });
#
#         function geo_json_b2d9cb477d755df1dad0a0049c08a072_add (data) {
#             geo_json_b2d9cb477d755df1dad0a0049c08a072
#                 .addData(data)
#                 .addTo(map_6bb712cbc04ada20c8791c84d50ac308);
#         }
#             geo_json_b2d9cb477d755df1dad0a0049c08a072_add({&quot;bbox&quot;: [126.92431728529574, 37.52419444704424, 126.92886485808684, 37.53050916717673], &quot;features&quot;: [{&quot;bbox&quot;: [126.92431728529574, 37.528695521738, 126.92545593726734, 37.529602349771], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.92432421238817, 37.528695521738], [126.92431728529574, 37.52959683833332], [126.92544902379107, 37.529602349771], [126.92545593726734, 37.52870103299733], [126.92432421238817, 37.528695521738]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;620&quot;, &quot;properties&quot;: {&quot;bd_archarea&quot;: 1.6274035574954864, &quot;bd_elvtent&quot;: 1.99

# %%
phase_grid_idxs = phase_results[phase_results['phase']<=10].grid_idx
gdf[gdf['grid_idx'].isin(phase_grid_idxs)].explore(column = 'bd_ilp')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75e612b3e749e9265dca101d9d2ae24d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75e612b3e749e9265dca101d9d2ae24d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75e612b3e749e9265dca101d9d2ae24d = L.map(
#                 &quot;map_75e612b3e749e9265dca101d9d2ae24d&quot;,
#                 {
#                     center: [37.524658793385555, 126.92664954566708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_75e612b3e749e9265dca101d9d2ae24d);
#
#
#
#
#
#             var tile_layer_3bbaebc3f596813ba5eec80c4ee4c3a2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_75e612b3e749e9265dca101d9d2ae24d);
#
#
#             map_75e612b3e749e9265dca101d9d2ae24d.fitBounds(
#                 [[37.51791260386979, 126.92097084073266], [37.531404982901314, 126.93232825060149]],
#                 {}
#             );
#
#
#         function geo_json_36f7c6524e7d710177171d955cb4ce0b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;595&quot;: case &quot;607&quot;: case &quot;612&quot;:
#                     return {&quot;color&quot;: &quot;#22a884&quot;, &quot;fillColor&quot;: &quot;#22a884&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;613&quot;:
#                     return {&quot;color&quot;: &quot;#1fa187&quot;, &quot;fillColor&quot;: &quot;#1fa187&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;614&quot;:
#                     return {&quot;color&quot;: &quot;#1fa287&quot;, &quot;fillColor&quot;: &quot;#1fa287&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;615&quot;:
#                     return {&quot;color&quot;: &quot;#3a548c&quot;, &quot;fillColor&quot;: &quot;#3a548c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;616&quot;:
#                     return {&quot;color&quot;: &quot;#482677&quot;, &quot;fillColor&quot;: &quot;#482677&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;617&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;618&quot;:
#                     return {&quot;color&quot;: &quot;#20928c&quot;, &quot;fillColor&quot;: &quot;#20928c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;619&quot;:
#                     return {&quot;color&quot;: &quot;#20a386&quot;, &quot;fillColor&quot;: &quot;#20a386&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;620&quot;:
#                     return {&quot;color&quot;: &quot;#31678e&quot;, &quot;fillColor&quot;: &quot;#31678e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;621&quot;:
#                     return {&quot;color&quot;: &quot;#453781&quot;, &quot;fillColor&quot;: &quot;#453781&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;622&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;625&quot;:
#                     return {&quot;color&quot;: &quot;#22a785&quot;, &quot;fillColor&quot;: &quot;#22a785&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;627&quot;:
#                     return {&quot;color&quot;: &quot;#34618d&quot;, &quot;fillColor&quot;: &quot;#34618d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;628&quot;:
#                     return {&quot;color&quot;: &quot;#1e9c89&quot;, &quot;fillColor&quot;: &quot;#1e9c89&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;629&quot;: case &quot;631&quot;:
#                     return {&quot;color&quot;:

# %% [markdown]
# #### 2. CBD Index

# %%
# for each grids, calculate CBD Index. CBD Index represents two;
# 1. CBDness
# 2. How each grid is similar to other grids in CBD Boundary

# for example, suppose there is very high building with sufficient people, business factor((1)suffices), 
# but if that building is not similar to other buildings around((2)not suffices) CBD Index must show low
# (=like Lionel messi in the amateur league, not in Ligue 1 league)
